# %% [markdown]
# <a href="https://colab.research.google.com/github/Belladonna333-eng/Atividades--Python/blob/main/testegithub1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("olá mundo")
print("curso técnico de informática")
